# %%
from server_configuration.helpers import modelling
modelling = modelling("data_right_price/data_localisee/")
X_train, X_test, Y_train, Y_test = modelling.preprocessing_and_splitting()
reg = modelling.load_model("server_configuration/saved_model.pkl")
y_pred = modelling.predict(reg, X_test)

# %%
modelling = modelling("data_right_price/data_localisee/")
X_train, X_test, Y_train, Y_test = modelling.preprocessing_and_splitting()

# %%
X_train, X_test, Y_train, Y_test = modelling.preprocessing_and_splitting()

# %%
reg = modelling.training(X_train, Y_train)

# %%
y_pred = modelling.predict(reg, X_test)

# %%
modelling.print_score(Y_test, y_pred)
# Out:
# R²: 0.7389615421530696
# RMSE: 0.5112532824525546
#
# MSE: 0.2613799188185116

# %%
reg_2 = modelling.load_model("server_configuration/saved_model.pkl")

# %%
y_pred_2 = modelling.predict(reg_2, X_test[:2])

# %%
y_pred_2
# Out:
# array([-0.18209913,  0.58377063], dtype=float32)

# %%
modelling.print_score(Y_test[:2], y_pred_2)
# Out:
# R²: 0.9051175991622318
# RMSE: 0.12645292440807962
#
# MSE: 0.0159903420913555

# %%
from server_configuration.helpers import plotting_functions

import pandas as pd
import geopandas as gpd

# %%
IDF_sample = pd.read_csv('data_right_price/data_localisee/sample_mutations_IDF_train_localized.csv')

geo_IDF_sample = gpd.GeoDataFrame(
    IDF_sample, geometry=gpd.points_from_xy(IDF_sample.longitude, IDF_sample.latitude))

# %%
plotting_functions(min_year=2014, max_year=2014).plot_map(geo_IDF_sample)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37f9f149a98c5be4e5954eec2a446f34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37f9f149a98c5be4e5954eec2a446f34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37f9f149a98c5be4e5954eec2a446f34 = L.map(
#                 &quot;map_37f9f149a98c5be4e5954eec2a446f34&quot;,
#                 {
#                     center: [48.857186680581776, 2.353999314721912],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9b30b445289761a7dab3a47bf42f4b3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37f9f149a98c5be4e5954eec2a446f34);
#
#
#             var marker_66868928460c9e16c6a44f5a1c6cd378 = L.marker(
#                 [48.8986972271354, 2.087890999036768],
#                 {}
#             ).addTo(map_37f9f149a98c5be4e5954eec2a446f34);
#
#
#         var popup_37e19114dbf011657f113fe9ab7de6c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e414be1365f6440bae88fe39f1a73cf4 = $(`&lt;div id=&quot;html_e414be1365f6440bae88fe39f1a73cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nature de la mutation: Vente&lt;br&gt;&lt;br&gt;Valeur foncière: 23000.0&lt;br&gt;&lt;br&gt;Date de la mutation: 15/7/2014&lt;br&gt;&lt;br&gt;Type de bien: UNE DEPENDANCE&lt;br&gt;&lt;br&gt;Surface du bien: 0.0 m^2&lt;br&gt;&lt;br&gt;CODE INSEE: 78551&lt;br&gt;&lt;br&gt;Section: AI&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_37e19114dbf011657f113fe9ab7de6c1.setContent(html_e414be1365f6440bae88fe39f1a73cf4);
#
#
#
#         marker_66868928460c9e16c6a44f5a1c6cd378.bindPopup(popup_37e19114dbf011657f113fe9ab7de6c1)
#         ;
#
#
#
#
#             var marker_beaf4d03239d1dd120f04c66983c19f2 = L.marker(
#                 [49.02186514888976, 2.158523220027728],
#                 {}
#             ).addTo(map_37f9f149a98c5be4e5954eec2a446f34);
#
#
#         var popup_211859206da02d384cc1055e355ce2fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b771842c231746b979d51dcd5d17bbc9 = $(`&lt;div id=&quot;html_b771842c231746b979d51dcd5d17bbc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nature de la mutation: Vente&lt;br&gt;&lt;br&gt;Valeur foncière: 171500.0&lt;br&gt;&lt;br&gt;Date de la mutation: 19/9/2014&lt;br&gt;&lt;br&gt;Type de bien: DES MAISONS&lt;br&gt;&lt;br&gt;Surface du bien: 126.0 m^2&lt;br&gt;&lt;br&gt;CODE INSEE: 95488&lt;br&gt;&lt;br&gt;Section: AD&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_211859206da02d384cc1055e355ce2fb.setContent(html_b771842c231746b979d51dcd5d17bbc9);
#
#
#
#         marker_beaf4d03239d1dd120f04c66983c19f2.bindPopup(popup_211859206da02d384cc1055e355ce2fb)
#         ;
#
#
#
#
#             var marker_417a6c8481067d9238d39e0a2d357e6b = L.marker(
#                 [49.00213341245541, 2.151045926623695],
#                 {}
#             ).addTo(map_37f9f149a98c5be4e5954eec2a446f34);
#
#
#         var popup_b91087c428df849e2bdfbd8ff7bedcee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f9315b818f80d88e869c10a378ffe11 = $(`&lt;div id=&quot;html_5f9315b818f80d88e869c10a378ffe11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nature de la mutation: Vente&lt;br&gt;&lt;br&gt;Valeur foncière: 545000.0&lt;br&gt;&lt;br&gt;Date de la mutation: 18/11/2014&lt;br&gt;&lt;br&gt;Type de bien: UNE MAISON&lt;br&gt;&lt;br&gt;Surface du bien: 88.0 m^2&lt;br&gt;&lt;br&gt;CODE INSEE: 95306&lt;br&gt;&lt;br&gt;Section: AL, BK&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_b91087c428df849e2bdfbd8ff7bedcee.setContent(html_5f9315b818f80d88e869c10a378ffe11);
#
#
#
#         marker_417a6c8481067d9238d39e0a2d357e6b.bindPopup(popup_b91087c428df849e2bdfbd8ff7bedcee)
#         ;
#
#
#
#
#             var marker_37ec12ef72e9ed321137b2cb1a574541 = L.marker(
#                 [48.83797117985503, 2.2471407748732],
#                 {}
#             ).addTo(map_37f9f149a98c5be4e5954eec2a446f34);
#
#
#         var popup_931da4ff5ebd18922bf0bea57e920ffc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9a3b7da9c9727dc67edfdd721aa4d09 = $(`&lt;div id=&quot;html_e9a3b7da9c9727dc67edfdd721aa4d09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nature de la mutation: Vente&lt;br&gt;&lt;br&gt;Valeur foncière: 1746400.0&lt;br&gt;&lt;br&gt;Date de la mutation: 29/4/2014&lt;br&gt;&lt;br&gt;Type de bien: UNE MAISON&lt;br&gt;&lt;br&gt;Surface du bien: 150.0 m^2&lt;br&gt;&lt;br&gt;CODE INSEE: 92012&lt;br&gt;&lt;br&gt;Section: AR&lt;b

# %%
# IDF = pd.read_csv('server_configuration/data_right_price/data_localisee/mutations_IDF_train_localized.csv', index_col='Unnamed: 0', low_memory=True)
# IDF_sample_100000 = IDF.sample(100000, random_state=123)

# %%
IDF_sample_100000 = pd.read_csv('server_configuration/data_right_price/data_localisee/sample_100000_mutations_IDF_train_localized.csv')

# %%
fig = plotting_functions(min_value=6500000).plot_yearly_figures(IDF_sample_100000)
fig.show()
